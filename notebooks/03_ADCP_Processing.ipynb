# %%
````xml
<!-- filepath: /Users/bell/Programs/EcoFOCIpy/notebooks/03_ADCP_Processing.ipynb -->
<VSCode.Cell language="markdown">
# ADCP Processing and Analysis

Learn how to process and analyze Acoustic Doppler Current Profiler (ADCP) data to understand ocean currents and water movement.

**Topics covered:**
- ADCP instrument fundamentals
- Loading and parsing ADCP data files
- Processing velocity profiles
- Creating flow visualizations (quiver plots, streamlines)
- Analyzing current speed and direction
- Time-series current analysis
- Quality control for velocity data

**Estimated time:** 30 minutes  
**Difficulty:** Advanced
</VSCode.Cell>
<VSCode.Cell language="python">
import warnings
warnings.filterwarnings('ignore')

import EcoFOCIpy
from EcoFOCIpy import instruments
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.quiver import Quiver

# Configure plotting
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (14, 8)

print(f"EcoFOCIpy version: {EcoFOCIpy.__version__}")
print("Libraries loaded ✓")
